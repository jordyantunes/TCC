# %% [markdown]
# # Análise Algoritmo Frame Diff

# %%
# carregamentos iniciais

import framediff
import matplotlib.pyplot as plt
import sys
import numpy as np
import util

def getdY(frame):
    return frame.dY


dY = np.vectorize(getdY)
videos = {'original' : './in/thecrimesofgrindelwaldTrim.mp4', 
          'blur' : './in/grindelwald_blur.avi',
          'text' : './in/grindelwald_text.avi',
          'truetext' : './in/grindelwald2_text.avi',
          'outro' : './in/outro.mp4'
         }

# %% [markdown]
# ## Plotar assinatura pura X filtrada

# %%
for i, v in videos.items():
    plt.figure(i)
    fingerprint = framediff.run(v)
    print(type(fingerprint))
    ass = dY(fingerprint)
    ass_lowpass = util.butter_lowpass_filter(ass, 3.5, 30.0)
    plt.title("Sinais pré e pós suavização {}".format(i))
    plt.plot(ass, label="Sinal original")
    plt.plot(ass_lowpass, label="Sinal filtrado")
    plt.legend()

plt.show()
# Out:
# --------------True FrameDiff---------------
# 262/263 (99.6%)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b0731026fb26> in <module>()
#       2     plt.figure(i)
#       3     fingerprint = framediff.run(v)
# ----> 4     ass = framediff.getindex(fingerprint, "dY", 0, 0)  # dY(fingerprint)
#       5     ass_lowpass = util.butter_lowpass_filter(ass, 3.5, 30.0)
#       6     plt.title("Sinais pré e pós suavização {}".format(i))
#
# ~\Documents\GitHub\TCC\src\trueframediff\framediff.py in getindex(feature, window_size, number_peaks, threashold)
#       7
#       8 def getindex(feature, window_size, number_peaks, threashold):
# ----> 9     print(type(feature))
#      10     exit(0)
#      11     dY = util.getParamVectorized(feature, "dY")
#
# ~\Anaconda3\envs\tcc\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2753             vargs.extend([kwargs[_n] for _n in names])
#    2754
# -> 2755         return self._vectorize_call(func=func, args=vargs)
#    2756
#    2757     def _get_ufunc_and_otypes(self, func, args):
#
# ~\Anaconda3\envs\tcc\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2823             res = func()
#    2824         else:
# -> 2825             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2826
#    2827             # Convert args to object arrays first
#
# ~\Anaconda3\envs\tcc\lib\site-packages\numpy\lib\function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2783
#    2784             inputs = [arg.flat[0] for arg in args]
# -> 2785             outputs = func(*inputs)
#    2786
#    2787             # Performance note: profiling indicates that -- for simple
#
# ~\Documents\GitHub\TCC\src\trueframediff\util.py in getParam(vect, param)
#      17
#      18 def getParam(vect, param):
# ---> 19     return vect[param]
#      20
#      21
#
# TypeError: 'Features' object is not subscriptable

# %% [markdown]
# ## Original X Cópia + Distorção

# %%
for i, v in videos.items():
    fingerprint = framediff.run(v)
    ass = dY(fingerprint)
    ass_lowpass = util.butter_lowpass_filter(ass, 3.5, 30.0)
    plt.plot(ass_lowpass, label=i)

plt.title("Sinais original e distorcido")
plt.legend()
plt.show()
# Out:
# --------------True FrameDiff---------------
# 262/263 (99.6%)
# --------------True FrameDiff---------------
# 263/264 (99.6%)
# --------------True FrameDiff---------------
# 263/264 (99.6%)
# --------------True FrameDiff---------------
# 263/264 (99.6%)
# --------------True FrameDiff---------------
# 241/242 (99.6%)
